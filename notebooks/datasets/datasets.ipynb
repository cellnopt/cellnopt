# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.dpi'] = 200
matplotlib.rcParams['figure.figsize'] = (12,8)
from cno import datasets

# %%
print(dir(datasets))
# Out:
# ['ExtLiverPCB', 'LiverDREAM', 'ToyMMB', 'ToyPB', 'ToyPB_True', 'ToyPCB', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', '_build_registers', '_registered', 'cnodata', 'importlib', 'register', 'registers']

# %%
# the plot method uses cellnopt.core behind the scene to fetch the pknmodel
# and data set and CNOGraph data structure
ToyMMB.plot()
# Out:
# INFO:root:dot -Tpng /tmp/tmpjtY48P.dot -o /tmp/tmpBE4ZxW.png

# %% [markdown]
# #### pathname to data and pknmodel are available given a tag name (e.g., ToyPB)

# %%
ToyMMB.model_filename
# Out:
# '/home/cokelaer/Work/github/cellnopt/cno/datasets/ToyMMB/PKN-ToyMMB.sif'

# %% [markdown]
# another way to get the data set filename is to use the **cnodata** function

# %%
pknmodel = datasets.cnodata('PKN-ToyMMB.sif')

# %% [markdown]
# #### available datasets are here

# %%
datasets.registers
# Out:
# ['MD-ExtLiverPCB.csv',
#  'MD-LiverDREAM.csv',
#  'MD-ToyMMB.csv',
#  'MD-ToyPB.csv',
#  'MD-ToyPB_True.csv',
#  'MD-ToyPCB.csv',
#  'PKN-ExtLiverPCB.sif',
#  'PKN-LiverDREAM.sif',
#  'PKN-ToyMMB.sif',
#  'PKN-ToyPB.sif',
#  'PKN-ToyPB_True.sif',
#  'PKN-ToyPCB.sif']

# %% [markdown]
#  plot() methods are avialable for each dataset
