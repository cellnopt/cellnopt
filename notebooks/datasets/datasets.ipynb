# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.dpi'] = 200
matplotlib.rcParams['figure.figsize'] = (12,8)
from cno import datasets

# %%
print(dir(datasets))
# Out:
# ['EGFR-ErbB_PCB2009', 'ExtLiverPCB', 'LiverDREAM', 'ToyMMB', 'ToyPB', 'ToyPB_True', 'ToyPCB', '__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '__path__', '_build_registers', '_registered', 'cnodata', 'directories', 'glob', 'importlib', 'os', 'pathname', 'register', 'registers', 'x']

# %%
# the plot method uses cellnopt.core behind the scene to fetch the pknmodel
# and data set and CNOGraph data structure
datasets.ToyMMB.plot()
# Out:
# /home/cokelaer/Work/virtualenv/svn-sysbiomed/trunk/cnolab/cellnopt/core/src/core/midas.py:577: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   value_experiments.replace("NaN", 0, inplace=True)
# INFO:root:dot -Tpng /tmp/tmpOVGKi7.dot -o /tmp/tmpZAxJgk.png

# %% [markdown]
# #### pathname to data and pknmodel are available given a tag name (e.g., ToyPB)

# %%
datasets.ToyMMB.model_filename
# Out:
# '/home/cokelaer/Work/github/cellnopt/cno/datasets/ToyMMB/PKN-ToyMMB.sif'

# %% [markdown]
# another way to get the data set filename is to use the **cnodata** function

# %%
pknmodel = datasets.cnodata('PKN-ToyMMB.sif')

# %% [markdown]
# #### available datasets are here

# %%
datasets.registers
# Out:
# ['MD-EGFR-ErbB_PCB2009.csv',
#  'MD-ExtLiverPCB.csv',
#  'MD-LiverDREAM.csv',
#  'MD-ToyMMB.csv',
#  'MD-ToyPB.csv',
#  'MD-ToyPB_True.csv',
#  'MD-ToyPCB.csv',
#  'PKN-EGFR-ErbB_PCB2009.sif',
#  'PKN-ExtLiverPCB.sif',
#  'PKN-LiverDREAM.sif',
#  'PKN-ToyMMB.sif',
#  'PKN-ToyMMB.xml',
#  'PKN-ToyPB.sif',
#  'PKN-ToyPB.xml',
#  'PKN-ToyPB_True.sif',
#  'PKN-ToyPCB.sif']

# %% [markdown]
#  plot() methods are avialable for each dataset
